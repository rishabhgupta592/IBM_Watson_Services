# %% [markdown]
# # Language Translator

# %%
import json
! pip install --upgrade "ibm-watson>=4.2.1" # To Install package . Add "!" sign
# Out:
# ...
#      |████████████████████████████████| 358kB 11.5MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 204kB 24.9MB/s eta 0:00:01
# ...
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/ce/4d/6e/ae352b7c7acdddf073aeb06617fbfeefaea9fcb6d7ae98800b
# ...
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/6a/42/50/f96888116b329578304f9dda4693cef6f3e76e18272d22cb6c
# Successfully built ibm-watson ibm-cloud-sdk-core
# ...

# %% [markdown]
# ## GET credentials
# Region specific URL where you have hosted your service
# > Dashborad - Services - Language translator - Service Credentials

# %%
# Add your credentials. Below cred won't work
API_KEY = "ogufaS1iFOLKiQKkhTQlUnvJ_fdsf fd"
URL = "https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/31aa834c-9a36-472c-fd-hgbc9c-a829324dfba5"

# %%
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator(API_KEY)
language_translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator
)

# %%
# Region wise URLs are there
URL =   "https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/31aa834c-9a36-472c-bc9c-a829324dfba5"
language_translator.set_service_url(URL)

# %% [markdown]
# ## Disabling SSL verification
# All Watson services use Secure Sockets Layer (SSL) (or Transport Layer Security (TLS)) for secure connections between the client and server. The connection is verified against the local certificate store to ensure authentication, integrity, and confidentiality.

# %%
language_translator.set_disable_ssl_verification(True)

# %% [markdown]
# ## Translation English to Spanish

# %%
translation = language_translator.translate(
    text='Hello',
    model_id='en-es').get_result()
print(json.dumps(translation, indent=2, ensure_ascii=False))
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# {
#   "translations": [
#     {
#       "translation": "Hola"
#     }
#   ],
#   "word_count": 1,
#   "character_count": 5
# }

# %% [markdown]
# # List identifiable languages

# %%
languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
#     {
#       "language": "en",
#       "name": "English"
#     },
# ...

# %% [markdown]
# # Identify language

# %%
language = language_translator.identify(
    'Language translator translates text from one language to another').get_result()
print(json.dumps(language, indent=2))
# Out:
# {
#   "languages": [
#     {
#       "language": "en",
#       "confidence": 0.9999983463154118
#     },
#     {
#       "language": "nb",
#       "confidence": 7.859135570789468e-07
#     },
#     {
#       "language": "nn",
#       "confidence": 3.9792067156591394e-07
#     },
#     {
#       "language": "da",
#       "confidence": 2.0056131983929264e-07
#     },
#     {
#       "language": "de",
#       "confidence": 9.166320073293297e-08
#     },
#     {
#       "language": "pt",
#       "confidence": 7.670297268149805e-08
#     },
#     {
#       "language": "sq",
#       "confidence": 2.242013262842194e-08
#     },
#     {
#       "language": "sk",
#       "confidence": 1.699626591082033e-08
#     },
#     {
#       "language": "sv",
#       "confidence": 8.073986399854288e-09
#     },
#     {
#       "language": "af",
#       "confidence": 6.714038361328556e-09
#     },
#     {
#       "language": "fr",
#       "confidence": 5.809089567032634e-09
#     },
#     {
# ...

# %% [markdown]
# # Available Model

# %%
models = language_translator.list_models().get_result()
print(json.dumps(models, indent=2))
# Out:
# {
#   "models": [
#     {
#       "model_id": "en-tr",
#       "source": "en",
#       "target": "tr",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-tr",
#       "training_log": null
#     },
#     {
#       "model_id": "en-he",
#       "source": "en",
#       "target": "he",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-he",
#       "training_log": null
#     },
#     {
#       "model_id": "en-da",
#       "source": "en",
#       "target": "da",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-da",
#       "training_log": null
#     },
#     {
# ...
